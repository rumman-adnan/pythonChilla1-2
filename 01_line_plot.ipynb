# %% [markdown]
# # Import libraries
# #### These libraries are necessary for data vizualization in python
# - Seaborn automatically install these libraries
# *numpy*
# *scipy*
# *pandas*
# *matplotlib*

# %% [markdown]
# # Adding Limits

# %%
#import libraries
import seaborn as sns
import matplotlib.pyplot as plt




#load dataset
flower = sns.load_dataset("iris")
#(check data set)
#flower  
sns.set_style("whitegrid")
# set_style(style=None, rc=None)

sns.lineplot(x="sepal_length", y="sepal_width", data=flower)
plt.title("Flowers Plot")

plt.xlim(4)
plt.ylim(2)

plt.show()

# %% [markdown]
# # Figure Size

# %%
#import libraries
import seaborn as sns
import matplotlib.pyplot as plt

#load dataset
flower = sns.load_dataset("iris")

# Change Figure Size
plt.figure(figsize=(8,10))

sns.lineplot(x="sepal_length", y="sepal_width", data=flower)
plt.title("Flowers Plot")

plt.show()
